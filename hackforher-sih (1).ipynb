# %% [markdown]
# **Preliminary Datasets used for the Women's Safety Ananlytics Project**

# %% [markdown]
# https://www.kaggle.com/datasets/rajanand/crime-in-india

# %% [markdown]
# https://www.kaggle.com/datasets/greeshmagirish/crime-against-women-20012014-india

# %% [markdown]
# https://www.kaggle.com/datasets/mpwolke/cusersmarildownloadsdomviolcsv

# %% [markdown]
# <code> https://www.kaggle.com/code/nageshsingh/gender-detection-using-inceptionv3-92-6-acc </code>
#
# Model with an <code>accuracy of 92.6</code>

# %% [markdown]
# https://www.kaggle.com/datasets/crawford/inceptionv3

# %% [markdown]
# https://www.kaggle.com/datasets/jessicali9530/celeba-dataset

# %% [markdown]
# https://www.kaggle.com/code/uzzivirus/age-and-gender-detection

# %% [markdown]
# https://www.kaggle.com/datasets/jangedoo/utkface-new

# %% [markdown]
# https://www.kaggle.com/datasets/cashutosh/gender-classification-dataset

# %% [markdown]
# <code>https://www.kaggle.com/code/brahimettanany/classification-accuracy-91</code>
#
# Model with an <code>accuracy of 91</code>

# %% [markdown]
# https://www.kaggle.com/datasets/cashutosh/gender-classification-dataset

# %% [markdown]
# https://www.kaggle.com/code/ahmedabdelkhaleq/gender-classification-dataset-ml

# %% [markdown]
# https://www.kaggle.com/datasets/elakiricoder/gender-classification-dataset

# %% [markdown]
# https://vaw-data.srhr.org/map

# %% [markdown]
# https://vaw-data.srhr.org/

# %% [markdown]
# https://www.kaggle.com/code/nurcankurt/face-detection-cnn

# %% [markdown]
# https://www.kaggle.com/datasets/nurcankurt/labels

# %% [markdown]
# https://www.kaggle.com/datasets/fareselmenshawii/face-detection-dataset

# %% [markdown]
# https://www.kaggle.com/datasets/sbaghbidi/human-faces-object-detection

# %% [markdown]
# https://www.kaggle.com/code/aruchomu/yolo-v3-object-detection-in-tensorflow

# %% [markdown]
# https://www.kaggle.com/datasets/aruchomu/data-for-yolo-v3-kernel
